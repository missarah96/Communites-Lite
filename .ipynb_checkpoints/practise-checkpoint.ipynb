# %%
from urllib.request import urlopen
import pandas as pd
import plotly.express as px
import json
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

df = pd.read_csv("processed_communities.csv")
df = df.merge(

geometry = [Point(xy) for xy in zip(df['longitude'], df['latitude'])]
gdf = GeoDataFrame(df, geometry=geometry)

# %%
gdf
# Out:
#               area  type    state   latitude   longitude  fold  population  \
# 0        Sheffield  city  Alabama  34.765089  -87.698641     2        0.00
# 1           Auburn  city  Alabama  32.609857  -85.480783     1        0.04
# 2           Daphne  city  Alabama  30.603525  -87.903605     7        0.00
# 3           Hoover  city  Alabama  33.350377  -86.834403    10        0.05
# 4       Tuscaloosa  city  Alabama  33.209561  -87.567526     5        0.11
# ...            ...   ...      ...        ...         ...   ...         ...
# 1989      Sheridan  city  Wyoming  44.797194 -106.956179     8        0.01
# 1990      Evanston  city  Wyoming  41.268246 -110.963758     6        0.00
# 1991      Gillette  city  Wyoming  44.290635 -105.501876     9        0.01
# 1992       Laramie  city  Wyoming  41.311367 -105.591101     3        0.03
# 1993  Rock Springs  city  Wyoming  41.586056 -109.219454     7        0.01
#
#       householdsize  racepctblack  racePctWhite  ...  PopDens  PctUsePubTrans  \
# 0              0.31          0.46          0.63  ...     0.13            0.01
# 1              0.37          0.32          0.70  ...     0.09            0.01
# 2              0.39          0.31          0.75  ...     0.08            0.01
# 3              0.35          0.06          0.93  ...     0.14            0.00
# 4              0.43          0.69          0.43  ...     0.14            0.03
# ...             ...           ...           ...  ...      ...             ...
# 1989           0.29          0.00          0.97  ...     0.15            0.00
# 1990           0.65          0.00          0.96  ...     0.09            0.11
# 1991           0.53          0.00          0.96  ...     0.11            0.11
# 1992           0.40          0.02          0.90  ...     0.20            0.02
# 1993           0.45          0.02          0.92  ...     0.09            0.32
#
#       PolicCars  PolicOperBudg  LemasPctPolicOnPatr  LemasGangUnitDeploy  \
# 0           NaN            NaN                  NaN                  NaN
# 1           NaN            NaN                  NaN                  NaN
# 2           NaN            NaN                  NaN                  NaN
# 3           NaN            NaN                  NaN                  NaN
# 4          0.06           0.02                 0.74                  1.0
# ...         ...            ...                  ...                  ...
# 1989        NaN            NaN                  NaN                  NaN
# 1990        NaN            NaN                  NaN                  NaN
# 1991        NaN            NaN                  NaN                  NaN
# 1992        NaN            NaN                  NaN                  NaN
# 1993        NaN            NaN                  NaN                  NaN
#
#       LemasPctOfficDrugUn  PolicBudgPerPop  violent_crime_rate  \
# 0                     0.0              NaN                0.10
# 1                     0.0              NaN                0.15
# 2                     0.0              NaN                0.05
# 3                     0.0              NaN                0.09
# 4                     1.0             0.12                0.51
# ...                   ...              ...                 ...
# 1989                  0.0              NaN                0.06
# 1990                  0.0              NaN                0.11
# 1991                  0.0              NaN                0.15
# 1992                  0.0              NaN                0.12
# 1993                  0.0              NaN                0.27
#
#                          geometry
# 0      POINT (-87.69864 34.76509)
# 1      POINT (-85.48078 32.60986)
# 2      POINT (-87.90360 30.60353)
# 3      POINT (-86.83440 33.35038)
# 4      POINT (-87.56753 33.20956)
# ...                           ...
# 1989  POINT (-106.95618 44.79719)
# 1990  POINT (-110.96376 41.26825)
# 1991  POINT (-105.50188 44.29064)
# 1992  POINT (-105.59110 41.31137)
# 1993  POINT (-109.21945 41.58606)
#
# [1994 rows x 130 columns]

# %%
# world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15)

# %%
color_scale = [(0, 'orange'), (1,'red')]

fig = px.scatter_mapbox(df, 
                        lat="latitude", 
                        lon="longitude", 
                        hover_name="state", 
                        hover_data=["state", "area"],
                        color="violent_crime_rate",
                        color_continuous_scale=color_scale,
                        size="violent_crime_rate",
                        zoom=2.5, 
                        height=800,
                        width=800)

fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
fig = px.choropleth(gdf, locations='state',
                    locationmode="USA-states", color='PopDens', scope="usa")
fig.show()

# %%
# with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
#     counties = json.load(response)

# fig = px.choropleth_mapbox(df, geojson=counties, locations='violent_crime_rate', color='PopDens',
#                            color_continuous_scale="Viridis",
#                            range_color=(0, 12),
#                            mapbox_style="carto-positron",
#                            zoom=3, center = {"lat": 37.0902, "lon": -95.7129},
#                            opacity=0.5,
#                            labels={'PopDens':'Population Density'}
#                           )
# fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# fig.show()
